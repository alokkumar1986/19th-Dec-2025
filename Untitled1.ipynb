# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/19th-Dec-2025/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "Aptech"
print(s[-1])
print(s[-2])
#print(s[-7])

print(s[-3:-1]) #ec

print(s[:-1])

print(s[-6:])
# Out:
# h
# c
# ec
# Aptec
# Aptech

# %%
s = "Aptech"
# Reverse the string using slicing
reversed_s = s[::-1]
print(reversed_s)
# Out:
# hcetpA

# %%
s = 'Aptech'
print(s.lower()) #aptech
print(s.upper()) #APTECH
# Out:
# aptech
# APTECH

# %%
s = '            Aptech       '
print(s.strip()) #Aptech
# Out:
# Aptech

# %%
s = 'We are learning python fundamentals'
s1 = s.split(" ")
print(s1)
# Out:
# ['We', 'are', 'learning', 'python', 'fundamentals']

# %%
#write a program to find number of words in a string.

s = 'We are learning python fundamentals'
s1 = s.split(" ")
print(len(s1))
# Out:
# 5

# %%
s = 'We are learning python fundamentals'
s1 = s.split("e")
print(s1)
# Out:
# ['W', ' ar', ' l', 'arning python fundam', 'ntals']

# %%
a = 'Aptech'
b = 'Learning'
c = a+b
print(c)
# Out:
# AptechLearning

# %%
a = 'Aptech'
b = 'Learning'
c = a+" "+b
print(c)
# Out:
# Aptech Learning

# %%
a = "Aptech"
b = "we are learning python in "+a
print(b)
# Out:
# we are learning python in Aptech

# %%
a = "Aptech"
b = f"we are learning python in {a}"
print(b)
# Out:
# we are learning python in Aptech

# %%
s = "Aptech Learning"

print(s[0:5].lower()+s[5].upper()+s[6:14].lower()+s[14].upper())
# Out:
# aptecH learninG
