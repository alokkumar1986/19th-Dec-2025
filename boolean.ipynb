# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/19th-Dec-2025/blob/main/boolean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = True

print(type(a))
# Out:
# <class 'bool'>

# %%
b = False

print(type(b))
# Out:
# <class 'bool'>

# %%
c = true
print(type(c))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4275846404.py in <cell line: 0>()
# ----> 1 c = true
#       2 print(type(c))
#
# NameError: name 'true' is not defined

# %%
d = 'true'
print(type(d))
# Out:
# <class 'str'>

# %%
a = 10
print(bool(a))
# Out:
# True

# %%
b = -10
print(bool(b))
# Out:
# True

# %%
c = 12.6
print(bool(c))
# Out:
# True

# %%
d = 0
print(bool(d))
# Out:
# False

# %%
s = "Aptech"
print(bool(s))
# Out:
# True

# %%
s1 = 'Learning'
print(bool(s1))
# Out:
# True

# %%
s2 = ''
print(bool(s2))
# Out:
# False

# %%
s3 = ""
print(bool(s3))
# Out:
# False

# %%
s4 = " "
print(bool(s4))
# Out:
# True

# %%
l = [1,2,3,4,5]
print(bool(l))
# Out:
# True

# %%
l1 = []
print(bool(l1))
# Out:
# False

# %%
t = (1,2,3,4,5)
print(bool(t))
# Out:
# True

# %%
t1 = ()
print(bool(t1))
# Out:
# False

# %%
print(bool(0.00))

print(bool(0.000001))
# Out:
# False
# True

# %%
x = 10
print(isinstance(x, int))
# Out:
# True

# %%
a = 10
b = 5

print(a+b) #15
print(a-b) #5
print(a*b) #50
print(a/b) #2.0
print(a%b) #0
print(a//b)#2
print(a**b) #100000
# Out:
# 15
# 5
# 50
# 2.0
# 0
# 2
# 100000

# %%
a = 10
a+=5
print(a)
a-=5
print(a)
a*=5
print(a)
a/=5
print(a)
a//=5
print(a)
a**=5
print(a)
# Out:
# 15
# 10
# 50
# 10.0
# 2.0
# 32.0

# %%
a = 10
b = 5
c = a and b
print(c)
# Out:
# 5

# %%
a = 0
b = 5
c = a and b
print(c)
# Out:
# 0

# %%
a = 5
b = 0
c = a and b
print(c)
# Out:
# 0

# %%
a = 10
b = 100
c = a or b
print(c)
# Out:
# 10

# %%
a = 10
b = 0
c = a or b
print(c)
# Out:
# 10

# %%
a = 0
b = 100
c = a or b
print(c)
# Out:
# 100
