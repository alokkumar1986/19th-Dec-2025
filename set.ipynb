# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/19th-Dec-2025/blob/main/set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = {1, 2, 3, 4, 5}

print(type(s)) #<class 'set'>
# Out:
# <class 'set'>

# %%
s = set((1,2,3,4,5))
print(type(s)) #<class 'set'>
# Out:
# <class 'set'>

# %%
s = {1, 2, 3, 4, 5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {1, 2, 3, 4, 5}
s[0] = 10
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1965260986.py in <cell line: 0>()
#       1 s = {1, 2, 3, 4, 5}
# ----> 2 s[0] = 10
#       3 print(s)
#
# TypeError: 'set' object does not support item assignment

# %%
s = {1, 2, 3, 3, 2, 4, 5}

print(s)
# Out:
# {1, 2, 3, 4, 5}
