# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/19th-Dec-2025/blob/main/controlflow1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Aptech"
if name=="Aptech":
 print('Name is Aptech')
print("End of the program")
# Out:
# Name is Aptech
# End of the program

# %%
if 10<20:
 print('10 is less than 20')
print('End of Program')
# Out:
# End of Program

# %%
name = input("Enter your name : ")
if name == "Ram" :
  print("Hello", name)
# Out:
# Enter your name : Ram
# Hello Ram

# %%
name = input("Enter your name : ")

if name == 'Ram':
  print("Hello",  name)
else:
  print("Hello Guest")
# Out:
# Enter your name : Aptech
# Hello Guest

# %%
mark = int(input("Enter your mark in Python (1-100) : "))

if mark >= 30 and mark < 50:
  print("Grade : C")
elif mark >= 50 and mark < 70:
  print("Grade : B")
elif mark >= 70 :
  print("Grade : A")
else:
  print("Fail")
# Out:
# Enter your mark in Python (1-100) : 15
# Fail
