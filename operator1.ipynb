# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/19th-Dec-2025/blob/main/operator1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
10 and 5
# Out:
# 5

# %%
0 and 5
# Out:
# 0

# %%
10 or  5
# Out:
# 10

# %%
0 or 5
# Out:
# 5

# %%
5 == 5
# Out:
# True

# %%
5 == 5.0
# Out:
# True

# %%
5 == "5"
# Out:
# False

# %%
'5' == "5"
# Out:
# True

# %%
5 == 5.01
# Out:
# False

# %%
a = 5
b = 5
a is b
# Out:
# True

# %%
a = 5
b = 5.0
a is b
# Out:
# False

# %%
a = 5
b = 5
a is not b
# Out:
# False

# %%
 a = 5
 b = 5.0
 a is not b
# Out:
# True

# %%
10 is 5
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipython-input-2117768762.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   10 is 5
# False

# %%
a = [1, 2, 3]
b = a
c = [1, 2, 3]

print(a)
print(b)
print(c)

print(a is b) #True
print(a is c) #False

print(a == b)
print(a == c)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# True
# False
# True
# True

# %%
a = 10
b = a
c = 10

print(a is b)
print(a is c)

print(a == b)
print(a == c)
# Out:
# True
# True
# True
# True

# %%
l = [1, 2, 3, 5]

print(3 in l)
print(4 in l)
print(4 not in l)
# Out:
# True
# False
# True

# %%
10 & 5
# Out:
# 0

# %%
10 | 5
# Out:
# 15

# %%
~5
# Out:
# -6

# %%
~-5
# Out:
# 4

# %%
10 ^ 5
# Out:
# 15

# %%
10 ^ 12
# Out:
# 6
