# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/19th-Dec-2025/blob/main/package.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try :
  import matplotlib
except:
  print('Package import failed. Package is not installed.')
else:
  print("Package imported successfully.")
finally:
  print('End.')
# Out:
# Package imported successfully.
# End.

# %%
try :
  from matplotlib import pyplot as plt
except:
  print('Module import failed. Package is not installed.')
else:
  print("Module imported successfully.")
finally:
  print('End.')
# Out:
# Package imported successfully.
# End.

# %%
try :
  import matplotlib.pyplot
except:
  print('Module import failed. Package is not installed.')
else:
  print("Module imported successfully.")
finally:
  print('End.')
# Out:
# Module imported successfully.
# End.

# %%
try :
  import matplotlib.pyplot as plt
except:
  print('Module import failed. Package is not installed.')
else:
  print("Module imported successfully.")
finally:
  print('End.')
