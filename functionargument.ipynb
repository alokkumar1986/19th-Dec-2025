# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/19th-Dec-2025/blob/main/functionargument.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def my_function(animal, name):
  print('I have a ', animal)
  print('My', animal, '\'s name is ', name)

my_function('dog', 'bhalu')
# Out:
# I have a  dog
# My dog 's name is  bhalu

# %%
def my_function( name, animal):
  print('I have a ', animal)
  print('My', animal, '\'s name is ', name)

my_function('dog', 'bhalu')
# Out:
# I have a  bhalu
# My bhalu 's name is  dog

# %%
def my_function(animal, name):
  print('I have a ', animal)
  print('My', animal, '\'s name is ', name)

my_function(animal = 'dog', name = 'bhalu')
# Out:
# I have a  dog
# My dog 's name is  bhalu

# %%
def my_function(animal, name):
  print('I have a ', animal)
  print('My', animal, '\'s name is ', name)

my_function(name = 'bhalu', animal = 'dog')
# Out:
# I have a  dog
# My dog 's name is  bhalu

# %%
def my_function(animal, name="bhalu"):
  print('I have a ', animal)
  print('My', animal, '\'s name is ', name)

my_function('dog')
# Out:
# I have a  dog
# My dog 's name is  bhalu

# %%
def my_function(animal, name="bhalu"):
  print('I have a ', animal)
  print('My', animal, '\'s name is ', name)

my_function('dog', "buddy")
# Out:
# I have a  dog
# My dog 's name is  buddy

# %%
def my_function(animal="cat", name):
  print('I have a ', animal)
  print('My', animal, '\'s name is ', name)

my_function('dog', "buddy")
# Out:
#   File "/tmp/ipykernel_198/1038903106.py", line 1
#     def my_function(animal="cat", name):
#                                   ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def my_function(animal="cat", name="pussy"):
  print('I have a ', animal)
  print('My', animal, '\'s name is ', name)

my_function('dog', "buddy")
# Out:
# I have a  dog
# My dog 's name is  buddy

# %%
def my_function(animal="cat", name="pussy"):
  print('I have a ', animal)
  print('My', animal, '\'s name is ', name)

my_function()
# Out:
# I have a  cat
# My cat 's name is  pussy
